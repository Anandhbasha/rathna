# %%
num = widgets.FloatText(
    value=5.5,description="Marks:"
)

display(num)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 num = widgets.FloatText(
#       2     value=5.5,description="Marks:"
#       3 )
#       5 display(num)
#
# NameError: name 'widgets' is not defined

# %%
import ipywidgets as widgets
from IPython.display import display
num = widgets.FloatText(value=5.5,description="Marks:")
display(num)
# Out:
# FloatText(value=5.5, description='Marks:')
